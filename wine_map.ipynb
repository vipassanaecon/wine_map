# %%
#Importing and manipulating our data
#1 #import our data
import pandas as pd

df = pd.read_csv(r"C:\Users\straw\Desktop\wine_map\napa_wine_full.csv", encoding= 'unicode_escape')
df
# Out:
#                     Winery                      Address        City  \
# 0    13th Vineyard by Cade       150 White Cottage Rd S      Angwin
# 1                1881 Napa      7856 St. Helena Highway    Oakville
# 2           4 Winds Winery         5870 Silverado Trail        Napa
# 3              4088 Winery          4088 Atlas Peak Rod        Napa
# 4              601 Cellars  2545 Napa Valley Corp. Dr C        Napa
# ..                     ...                          ...         ...
# 789            Young Ridge              945 Lincoln Ave        Napa
# 790       Y Rousseau Wines           902 Enterprise Way        Napa
# 791           Zakin Estate     290 Crystal Springs Road  St. Helena
# 792      Zeitgeist Cellars                 P.O. Box 552  St. Helena
# 793              ZD Winery         8383 Silverado Trail        Napa
#
#                       Website         Phone  NWP      App Cave  \
# 0        www.13thvineyard.com      968-5747    X      Yes  Yes
# 1            www.1881napa.com      948-6099    X       No  NaN
# 2        www.4windswinery.com      294-8783    X  Private  Yes
# 3                         NaN      927-0662  NaN  Private  NaN
# 4              601cellars.com      927-3574    X      Yes  NaN
# ..                        ...           ...  ...      ...  ...
# 789        www.youngridge.com      265-8400  NaN  Private  NaN
# 790    www.yrousseauwines.com      287-3471    X  Private  NaN
# 791        www.zakinwines.com  415 793-6354    X  Private  NaN
# 792  www.zeitgeistcellars.com      480-1538    X  Private  NaN
# 793           www.zdwines.com      963-5188    X       No  NaN
#
#                                    Notes/Labels
# 0                                           NaN
# 1               Oakville Wine Merchant + Museum
# 2                                           NaN
# 3    Bialla, Ripe Peak Vineyard. Wines 2 China?
# 4                                           NaN
# ..                                          ...
# 789                            Still producing?
# 790        Mt. Veeder wine, also non Napa wines
# 791                                         NaN
# 792                                         NaN
# 793                                Abacus label
#
# [794 rows x 9 columns]

# %%
#2 #creating our Map Address column
df['Map Address'] = df['Address'].astype(str) + ',' + \
                  df['City'] + ',' + 'CA'
df.head()
# Out:
#                   Winery                      Address      City  \
# 0  13th Vineyard by Cade       150 White Cottage Rd S    Angwin
# 1              1881 Napa      7856 St. Helena Highway  Oakville
# 2         4 Winds Winery         5870 Silverado Trail      Napa
# 3            4088 Winery          4088 Atlas Peak Rod      Napa
# 4            601 Cellars  2545 Napa Valley Corp. Dr C      Napa
#
#                 Website     Phone  NWP      App Cave  \
# 0  www.13thvineyard.com  968-5747    X      Yes  Yes
# 1      www.1881napa.com  948-6099    X       No  NaN
# 2  www.4windswinery.com  294-8783    X  Private  Yes
# 3                   NaN  927-0662  NaN  Private  NaN
# 4        601cellars.com  927-3574    X      Yes  NaN
#
#                                  Notes/Labels  \
# 0                                         NaN
# 1             Oakville Wine Merchant + Museum
# 2                                         NaN
# 3  Bialla, Ripe Peak Vineyard. Wines 2 China?
# 4                                         NaN
#
#                            Map Address
# 0     150 White Cottage Rd S,Angwin,CA
# 1  7856 St. Helena Highway,Oakville,CA
# 2         5870 Silverado Trail,Napa,CA
# 3          4088 Atlas Peak Rod,Napa,CA
# 4  2545 Napa Valley Corp. Dr C,Napa,CA

# %%
#3 #drop all P.O. box addresses
df_copy = df[df["Address"].str.contains("P.O. Box")==False].copy()
df = df_copy
df
# Out:
#                     Winery                      Address        City  \
# 0    13th Vineyard by Cade       150 White Cottage Rd S      Angwin
# 1                1881 Napa      7856 St. Helena Highway    Oakville
# 2           4 Winds Winery         5870 Silverado Trail        Napa
# 3              4088 Winery          4088 Atlas Peak Rod        Napa
# 4              601 Cellars  2545 Napa Valley Corp. Dr C        Napa
# ..                     ...                          ...         ...
# 788        Young Inglewood           1919 Inglewood Ave  St. Helena
# 789            Young Ridge              945 Lincoln Ave        Napa
# 790       Y Rousseau Wines           902 Enterprise Way        Napa
# 791           Zakin Estate     290 Crystal Springs Road  St. Helena
# 793              ZD Winery         8383 Silverado Trail        Napa
#
#                     Website         Phone  NWP      App Cave  \
# 0      www.13thvineyard.com      968-5747    X      Yes  Yes
# 1          www.1881napa.com      948-6099    X       No  NaN
# 2      www.4windswinery.com      294-8783    X  Private  Yes
# 3                       NaN      927-0662  NaN  Private  NaN
# 4            601cellars.com      927-3574    X      Yes  NaN
# ..                      ...           ...  ...      ...  ...
# 788  www.younginglewood.com      200-4572    X      Yes  NaN
# 789      www.youngridge.com      265-8400  NaN  Private  NaN
# 790  www.yrousseauwines.com      287-3471    X  Private  NaN
# 791      www.zakinwines.com  415 793-6354    X  Private  NaN
# 793         www.zdwines.com      963-5188    X       No  NaN
#
#                                    Notes/Labels  \
# 0                                           NaN
# 1               Oakville Wine Merchant + Museum
# 2                                           NaN
# 3    Bialla, Ripe Peak Vineyard. Wines 2 China?
# 4                                           NaN
# ..                                          ...
# 788                                         NaN
# 789                            Still producing?
# 790        Mt. Veeder wine, also non Napa wines
# 791                                         NaN
# 793                                Abacus label
#
#                                 Map Address
# 0          150 White Cottage Rd S,Angwin,CA
# 1       7856 St. Helena Highway,Oakville,CA
# 2              5870 Silverado Trail,Napa,CA
# 3               4088 Atlas Peak Rod,Napa,CA
# 4       2545 Napa Valley Corp. Dr C,Napa,CA
# ..                                      ...
# 788        1919 Inglewood Ave,St. Helena,CA
# 789                 945 Lincoln Ave,Napa,CA
# 790              902 Enterprise Way,Napa,CA
# 791  290 Crystal Springs Road,St. Helena,CA
# 793            8383 Silverado Trail,Napa,CA
#
# [743 rows x 10 columns]

# %%
#4 import geopy and Nominatim geocoding service
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="Wine Map", timeout=10)

# %%
#5 #assign our geocode variable and use RateLimiter function
from geopy.extra.rate_limiter import RateLimiter

geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# %%
#6 create geocode Location column 
df['Location'] = df['Map Address'].apply(geocode) #takes about 13minutes
df.head()
# Out:
#                   Winery                      Address      City  \
# 0  13th Vineyard by Cade       150 White Cottage Rd S    Angwin
# 1              1881 Napa      7856 St. Helena Highway  Oakville
# 2         4 Winds Winery         5870 Silverado Trail      Napa
# 3            4088 Winery          4088 Atlas Peak Rod      Napa
# 4            601 Cellars  2545 Napa Valley Corp. Dr C      Napa
#
#                 Website     Phone  NWP      App Cave  \
# 0  www.13thvineyard.com  968-5747    X      Yes  Yes
# 1      www.1881napa.com  948-6099    X       No  NaN
# 2  www.4windswinery.com  294-8783    X  Private  Yes
# 3                   NaN  927-0662  NaN  Private  NaN
# 4        601cellars.com  927-3574    X      Yes  NaN
#
#                                  Notes/Labels  \
# 0                                         NaN
# 1             Oakville Wine Merchant + Museum
# 2                                         NaN
# 3  Bialla, Ripe Peak Vineyard. Wines 2 China?
# 4                                         NaN
#
#                            Map Address  \
# 0     150 White Cottage Rd S,Angwin,CA
# 1  7856 St. Helena Highway,Oakville,CA
# 2         5870 Silverado Trail,Napa,CA
# 3          4088 Atlas Peak Rod,Napa,CA
# 4  2545 Napa Valley Corp. Dr C,Napa,CA
#
#                                             Location
# 0  (150, White Cottage Road South, Angwin, Napa C...
# 1                                               None
# 2  (Silverado Trail, Napa, Napa County, Californi...
# 3                                               None
# 4                                               None

# %%
#7 #drop all addresses listed as "None"
df_copy = df[df['Location'].notna()].copy()
df = df_copy
df
# Out:
#                     Winery                     Address        City  \
# 0    13th Vineyard by Cade      150 White Cottage Rd S      Angwin
# 2           4 Winds Winery        5870 Silverado Trail        Napa
# 5                7 Cellars     8301 St. Helena Highway        Napa
# 6           70s Love Wines  4105 Chiles Pope Valley Rd        Napa
# 10         Accendo Cellars          588 Zinfandel Lane  St. Helena
# ..                     ...                         ...         ...
# 787           Yates Family           4723 Redwood Road        Napa
# 788        Young Inglewood          1919 Inglewood Ave  St. Helena
# 789            Young Ridge             945 Lincoln Ave        Napa
# 790       Y Rousseau Wines          902 Enterprise Way        Napa
# 793              ZD Winery        8383 Silverado Trail        Napa
#
#                          Website         Phone  NWP      App Cave  \
# 0           www.13thvineyard.com      968-5747    X      Yes  Yes
# 2           www.4windswinery.com      294-8783    X  Private  Yes
# 5               www.7cellars.com  925 984-1531  NaN      NaN  NaN
# 6            www.70slovewine.com           NaN    X  Private  NaN
# 10        www.accendocellars.com  240 707-0311    X      Yes  NaN
# ..                           ...           ...  ...      ...  ...
# 787  www.yatesfamilyvineyard.com      226-1800    X  Private  NaN
# 788       www.younginglewood.com      200-4572    X      Yes  NaN
# 789           www.youngridge.com      265-8400  NaN  Private  NaN
# 790       www.yrousseauwines.com      287-3471    X  Private  NaN
# 793              www.zdwines.com      963-5188    X       No  NaN
#
#                                Notes/Labels  \
# 0                                       NaN
# 2                                       NaN
# 5    John Elway, produced at ONEHOPE Winery
# 6                                       NaN
# 10                     Wheeler Farms Winery
# ..                                      ...
# 787         Used to be Napa Redwoods Estate
# 788                                     NaN
# 789                        Still producing?
# 790    Mt. Veeder wine, also non Napa wines
# 793                            Abacus label
#
#                             Map Address  \
# 0      150 White Cottage Rd S,Angwin,CA
# 2          5870 Silverado Trail,Napa,CA
# 5       8301 St. Helena Highway,Napa,CA
# 6    4105 Chiles Pope Valley Rd,Napa,CA
# 10     588 Zinfandel Lane,St. Helena,CA
# ..                                  ...
# 787           4723 Redwood Road,Napa,CA
# 788    1919 Inglewood Ave,St. Helena,CA
# 789             945 Lincoln Ave,Napa,CA
# 790          902 Enterprise Way,Napa,CA
# 793        8383 Silverado Trail,Napa,CA
#
#                                               Location
# 0    (150, White Cottage Road South, Angwin, Napa C...
# 2    (Silverado Trail, Napa, Napa County, Californi...
# 5    (8301, Saint Helena Highway, Rutherford, Napa ...
# 6    (Chiles Pope Valley Road, Pope Valley, Napa Co...
# 10   (588, Zinfandel Lane, Zinfandel, Napa County, ...
# ..                                                 ...
# 787  (4723, Redwood Road, Napa County, California, ...
# 788  (1919, Inglewood Avenue, Thoman, Napa County, ...
# 789  (945, Lincoln Avenue, City of Napa Corporate Y...
# 790  (902, Enterprise Way, Shipyard Acres, Napa, Na...
# 793  (Silverado Trail, Napa, Napa County, Californi...
#
# [505 rows x 11 columns]

# %%
#8 #create “Point” column that lists longitude, latitude, and altitude
df['Point'] = df['Location'].apply(lambda loc: tuple(loc.point) if loc else None)
df.head()
# Out:
#                    Winery                     Address        City  \
# 0   13th Vineyard by Cade      150 White Cottage Rd S      Angwin
# 2          4 Winds Winery        5870 Silverado Trail        Napa
# 5               7 Cellars     8301 St. Helena Highway        Napa
# 6          70s Love Wines  4105 Chiles Pope Valley Rd        Napa
# 10        Accendo Cellars          588 Zinfandel Lane  St. Helena
#
#                    Website         Phone  NWP      App Cave  \
# 0     www.13thvineyard.com      968-5747    X      Yes  Yes
# 2     www.4windswinery.com      294-8783    X  Private  Yes
# 5         www.7cellars.com  925 984-1531  NaN      NaN  NaN
# 6      www.70slovewine.com           NaN    X  Private  NaN
# 10  www.accendocellars.com  240 707-0311    X      Yes  NaN
#
#                               Notes/Labels  \
# 0                                      NaN
# 2                                      NaN
# 5   John Elway, produced at ONEHOPE Winery
# 6                                      NaN
# 10                    Wheeler Farms Winery
#
#                            Map Address  \
# 0     150 White Cottage Rd S,Angwin,CA
# 2         5870 Silverado Trail,Napa,CA
# 5      8301 St. Helena Highway,Napa,CA
# 6   4105 Chiles Pope Valley Rd,Napa,CA
# 10    588 Zinfandel Lane,St. Helena,CA
#
#                                              Location  \
# 0   (150, White Cottage Road South, Angwin, Napa C...
# 2   (Silverado Trail, Napa, Napa County, Californi...
# 5   (8301, Saint Helena Highway, Rutherford, Napa ...
# 6   (Chiles Pope Valley Road, Pope Valley, Napa Co...
# 10  (588, Zinfandel Lane, Zinfandel, Napa County, ...
#
#                                              Point
# 0                    (38.567471, -122.457164, 0.0)
# 2                  (38.2922151, -122.2752447, 0.0)
# 5   (38.447348065043926, -122.41226936847224, 0.0)
# 6                  (38.5690433, -122.3906201, 0.0)
# 10    (38.4869715418745, -122.43680905050326, 0.0)

# %%
#9 #split up the Point column
df[['Latitude', 'Longitude', 'Altitude']] = pd.DataFrame(df['Point'].tolist(), index=df.index)
df.head()
# Out:
#                    Winery                     Address        City  \
# 0   13th Vineyard by Cade      150 White Cottage Rd S      Angwin
# 2          4 Winds Winery        5870 Silverado Trail        Napa
# 5               7 Cellars     8301 St. Helena Highway        Napa
# 6          70s Love Wines  4105 Chiles Pope Valley Rd        Napa
# 10        Accendo Cellars          588 Zinfandel Lane  St. Helena
#
#                    Website         Phone  NWP      App Cave  \
# 0     www.13thvineyard.com      968-5747    X      Yes  Yes
# 2     www.4windswinery.com      294-8783    X  Private  Yes
# 5         www.7cellars.com  925 984-1531  NaN      NaN  NaN
# 6      www.70slovewine.com           NaN    X  Private  NaN
# 10  www.accendocellars.com  240 707-0311    X      Yes  NaN
#
#                               Notes/Labels  \
# 0                                      NaN
# 2                                      NaN
# 5   John Elway, produced at ONEHOPE Winery
# 6                                      NaN
# 10                    Wheeler Farms Winery
#
#                            Map Address  \
# 0     150 White Cottage Rd S,Angwin,CA
# 2         5870 Silverado Trail,Napa,CA
# 5      8301 St. Helena Highway,Napa,CA
# 6   4105 Chiles Pope Valley Rd,Napa,CA
# 10    588 Zinfandel Lane,St. Helena,CA
#
#                                              Location  \
# 0   (150, White Cottage Road South, Angwin, Napa C...
# 2   (Silverado Trail, Napa, Napa County, Californi...
# 5   (8301, Saint Helena Highway, Rutherford, Napa ...
# 6   (Chiles Pope Valley Road, Pope Valley, Napa Co...
# 10  (588, Zinfandel Lane, Zinfandel, Napa County, ...
#
#                                              Point   Latitude   Longitude  \
# 0                    (38.567471, -122.457164, 0.0)  38.567471 -122.457164
# 2                  (38.2922151, -122.2752447, 0.0)  38.292215 -122.275245
# 5   (38.447348065043926, -122.41226936847224, 0.0)  38.447348 -122.412269
# 6                  (38.5690433, -122.3906201, 0.0)  38.569043 -122.390620
# 10    (38.4869715418745, -122.43680905050326, 0.0)  38.486972 -122.436809
#
#     Altitude
# 0        0.0
# 2        0.0
# 5        0.0
# 6        0.0
# 10       0.0

# %%
#10 import folium and create map
import folium

map = folium.Map(
    location=[38.297539, -122.286865],
    tiles='cartodbpositron',
    zoom_start=12,
)
df.apply(lambda row:folium.Marker(location=[row["Latitude"], row["Longitude"]], tooltip=row["Winery"]).add_to(map), axis=1)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c97ee32534b44661a2c3908605ce8144%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c97ee32534b44661a2c3908605ce8144%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c97ee32534b44661a2c3908605ce8144%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c97ee32534b44661a2c3908605ce8144%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.297539%2C%20-122.286865%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
#11 #alternative map version
map = folium.Map(
    location=[38.297539, -122.286865],
    tiles='cartodbpositron',
    zoom_start=12,
)
df.apply(lambda row:folium.CircleMarker(location=[row["Latitude"], row["Longitude"]], tooltip=row["Winery"], fill=True, color = 'red',  radius=1).add_to(map), axis=1)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7bf2fed8d4784b1da0a75835680d0c16%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7bf2fed8d4784b1da0a75835680d0c16%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7bf2fed8d4784b1da0a75835680d0c16%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7bf2fed8d4784b1da0a75835680d0c16%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.297539%2C%20-122.286865%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...
